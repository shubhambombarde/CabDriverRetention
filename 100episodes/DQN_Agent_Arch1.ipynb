# %% [markdown]
# ### Cab-Driver Agent

# %%
# Importing libraries
import numpy as np
import random
import math
from collections import deque
import collections
import pickle
import time

# for building DQN model
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# for plotting graphs
import matplotlib.pyplot as plt

# Import the environment
from Env import CabDriver

# %% [markdown]
# #### Defining Time Matrix

# %%
# Loading the time matrix provided
Time_matrix = np.load("TM.npy")

# %% [markdown]
# #### Tracking the state-action pairs for checking convergence

# %%
#Defining a function to save the Q-dictionary as a pickle file
def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Agent Class
#
# If you are using this framework, you need to fill the following to complete the following code block:
# 1. State and Action Size
# 2. Hyperparameters
# 3. Create a neural-network model in function 'build_model()'
# 4. Define epsilon-greedy strategy in function 'get_action()'
# 5. Complete the function 'append_sample()'. This function appends the recent experience tuple <state, action, reward, new-state> to the memory
# 6. Complete the 'train_model()' function with following logic:
#    - If the memory size is greater than mini-batch size, you randomly sample experiences from memory as per the mini-batch size and do the following:
#       - Initialise your input and output batch for training the model
#       - Calculate the target Q value for each sample: reward + gamma*max(Q(s'a,))
#       - Get Q(s', a) values from the last trained model
#       - Update the input batch as your encoded state and output batch as your Q-values
#       - Then fit your DQN model using the updated input and output batch.

# %%
class DQNAgent:
    def __init__(self, state_size, action_size):
        # Define size of state and action
        self.state_size = state_size
        self.action_size = action_size

        # Write here: Specify you hyper parameters for the DQN
        self.discount_factor = 0.95
        self.learning_rate = 0.01
        self.epsilon = 1
        self.epsilon_max = 1
        self.epsilon_decay = -0.0005 #for 15k
        #self.epsilon_decay = -0.00015 #for 20k
        self.epsilon_min = 0.00001
        
        self.batch_size = 32

        # create replay memory using deque
        self.memory = deque(maxlen=2000)

        # Initialize the value of the states tracked
        self.states_tracked = []
        
        # We are going to track state [0,0,0] and action (0,2) at index 2 in the action space.
        self.track_state = np.array(env.state_encod_arch1([0,0,0])).reshape(1, 36)

        # create main model and target model
        self.model = self.build_model()

    # approximate Q function using Neural Network
    def build_model(self):
        """
        Function that takes in the agent and constructs the network
        to train it
        @return model
        @params agent
        """
        input_shape = self.state_size
        model = Sequential()
        # Write your code here: Add layers to your neural nets       
        model.add(Dense(32, input_dim=self.state_size, activation='relu', kernel_initializer='he_uniform'))
        model.add(Dense(32, activation='relu', kernel_initializer='he_uniform'))
        # the output layer: output is of size num_actions
        model.add(Dense(self.action_size, activation='relu', kernel_initializer='he_uniform'))
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))
        model.summary
        return model

    def get_action(self, state, possible_actions_index, actions):
        """
        get action in a state according to an epsilon-greedy approach
        possible_actions_index, actions are the 'ride requests' that teh driver got.
        """        
        # get action from model using epsilon-greedy policy
        # Decay in ε after each episode       
        if np.random.rand() <= self.epsilon:
            # explore: choose a random action from the ride requests
            return random.choice(possible_actions_index)
        else:
            # choose the action with the highest q(s, a)
            # the first index corresponds to the batch size, so
            # reshape state to (1, state_size) so that the first index corresponds to the batch size
            state = np.array(env.state_encod_arch1(state)).reshape(1, 36)

            # Use the model to predict the Q_values.
            q_value = self.model.predict(state)

            # truncate the array to only those actions that are part of the ride  requests.
            q_vals_possible = [q_value[0][i] for i in possible_actions_index]

            return possible_actions_index[np.argmax(q_vals_possible)]

    def append_sample(self, state, action_index, reward, next_state, done):
        """appends the new agent run output to replay buffer"""
        self.memory.append((state, action_index, reward, next_state, done))
        
    # pick samples randomly from replay memory (with batch_size) and train the network
    def train_model(self):
        """ 
        Function to train the model on eacg step run.
        Picks the random memory events according to batch size and 
        runs it through the network to train it.
        """
        if len(self.memory) > self.batch_size:
            # Sample batch from the memory
            mini_batch = random.sample(self.memory, self.batch_size)
            # initialise two matrices - update_input and update_output
            update_input = np.zeros((self.batch_size, self.state_size))
            update_output = np.zeros((self.batch_size, self.state_size))
            actions, rewards, done = [], [], []

            # populate update_input and update_output and the lists rewards, actions, done
            for i in range(self.batch_size):
                state, action, reward, next_state, done_boolean = mini_batch[i]
                update_input[i] = env.state_encod_arch1(state)     
                actions.append(action)
                rewards.append(reward)
                update_output[i] = env.state_encod_arch1(next_state)
                done.append(done_boolean)

            # predict the target q-values from states s
            target = self.model.predict(update_input)
            # target for q-network
            target_qval = self.model.predict(update_output)


            # update the target values
            for i in range(self.batch_size):
                if done[i]:
                    target[i][actions[i]] = rewards[i]
                else: # non-terminal state
                    target[i][actions[i]] = rewards[i] + self.discount_factor * np.max(target_qval[i])
            # model fit
            self.model.fit(update_input, target, batch_size=self.batch_size, epochs=1, verbose=0)
            
    def save_tracking_states(self):
        # Use the model to predict the q_value of the state we are tacking.
        q_value = self.model.predict(self.track_state)
        
        # Grab the q_value of the action index that we are tracking.
        self.states_tracked.append(q_value[0][2])
        
    def save_test_states(self):
        # Use the model to predict the q_value of the state we are tacking.
        q_value = self.model.predict(self.track_state)
        
        # Grab the q_value of the action index that we are tracking.
        self.states_test.append(q_value[0][2])

    def save(self, name):
        self.model.save(name)

# %%
# Episodes = 15000
Episodes = 100

episode_time = 24*30 #30 days before which car has to be recharged
m = 5
t = 24
d = 7

# Invoke Env class
env = CabDriver()
action_space, state_space, state = env.reset()

# Set up state and action sizes.
state_size = m+t+d
action_size = len(action_space)

# Invoke agent class
agent = DQNAgent(action_size=action_size, state_size=state_size)

# to store rewards in each episode
rewards_per_episode, episodes = [], []
# Rewards for state [0,0,0] being tracked.
rewards_init_state = []
# Out:
# C:\ProgramData\Anaconda3\envs\datascience37\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %% [markdown]
# ### DQN block

# %%
start_time = time.time()
score_tracked = []

for episode in range(Episodes):

    # Write code here
    # Call the environment
    # Call all the initialised variables of the environment
    #Call the DQN agent
    done = False
    score = 0
    track_reward = False

    # reset at the start of each episode
    env = CabDriver()
    action_space, state_space, state = env.reset()
    # Save the initial state so that reward can be tracked if initial state is [0,0,0]
    initial_state = env.state_init


    total_time = 0  # Total time driver rode in this episode
    
    
    while not done:
        # 1. Get a list of the ride requests driver got.
        possible_actions_indices, actions = env.requests(state)
        # 2. Pick epsilon-greedy action from possible actions for the current state.
        action = agent.get_action(state, possible_actions_indices, actions)

        # 3. Evaluate your reward and next state
        reward, next_state, step_time = env.step(state, env.action_space[action], Time_matrix)
        # 4. Total time driver rode in this episode
        total_time += step_time
        if (total_time > episode_time):
            # if ride does not complete in stipu;ated time skip
            # it and move to next episode.
            done = True
        else:
            # 5. Append the experience to the memory
            agent.append_sample(state, action, reward, next_state, done)
            # 6. Train the model by calling function agent.train_model
            agent.train_model()
            # 7. Keep a track of rewards, Q-values, loss
            score += reward
            state = next_state

    # store total reward obtained in this episode
    rewards_per_episode.append(score)
    episodes.append(episode)
    

    # epsilon decay
    agent.epsilon = (1 - 0.00001) * np.exp(agent.epsilon_decay * episode)

    print("episode {0}, reward {1}, memory_length {2}, epsilon {3} total_time {4}".format(episode,
                                                                         score,
                                                                         len(agent.memory),
                                                                         agent.epsilon, total_time))
    # Save the Q_value of the state, action pair we are tracking
    if ((episode + 1) % 5 == 0):
        agent.save_tracking_states()

    # Total rewards per episode
    score_tracked.append(score)

    if(episode % 1000 == 0):
        print("Saving Model {}".format(episode))
        agent.save(name="model_weights.h5")
    
elapsed_time = time.time() - start_time
print(elapsed_time)
# Out:
# episode 0, reward -192.0, memory_length 113, epsilon 0.99999 total_time 725.0
# Saving Model 0
# episode 1, reward -359.0, memory_length 250, epsilon 0.9994901299779195 total_time 728.0
# episode 2, reward -31.0, memory_length 377, epsilon 0.9989905098283768 total_time 721.0
# episode 3, reward -397.0, memory_length 524, epsilon 0.9984911394264665 total_time 727.0
# episode 4, reward 50.0, memory_length 659, epsilon 0.9979920186473464 total_time 724.0
# episode 5, reward -157.0, memory_length 785, epsilon 0.9974931473662362 total_time 729.0
# episode 6, reward -402.0, memory_length 922, epsilon 0.996994525458418 total_time 721.0
# episode 7, reward 137.0, memory_length 1086, epsilon 0.9964961527992363 total_time 726.0
# episode 8, reward 83.0, memory_length 1214, epsilon 0.9959980292640981 total_time 727.0
# episode 9, reward -93.0, memory_length 1349, epsilon 0.9955001547284723 total_time 726.0
# episode 10, reward -108.0, memory_length 1493, epsilon 0.9950025290678904 total_time 726.0
# episode 11, reward -85.0, memory_length 1634, epsilon 0.994505152157946 total_time 732.0
# episode 12, reward -6.0, memory_length 1769, epsilon 0.9940080238742948 total_time 725.0
# episode 13, reward 59.0, memory_length 1913, epsilon 0.9935111440926547 total_time 721.0
# episode 14, reward -118.0, memory_length 2000, epsilon 0.9930145126888058 total_time 724.0
# episode 15, reward -278.0, memory_length 2000, epsilon 0.9925181295385903 total_time 723.0
# episode 16, reward -132.0, memory_length 2000, epsilon 0.9920219945179123 total_time 726.0
# episode 17, reward -281.0, memory_length 2000, epsilon 0.9915261075027382 total_time 726.0
# episode 18, reward -130.0, memory_length 2000, epsilon 0.9910304683690959 total_time 724.0
# episode 19, reward -331.0, memory_length 2000, epsilon 0.9905350769930761 total_time 727.0
# episode 20, reward -265.0, memory_length 2000, epsilon 0.9900399332508306 total_time 723.0
# episode 21, reward -202.0, memory_length 2000, epsilon 0.9895450370185737 total_time 730.0
# episode 22, reward -43.0, memory_length 2000, epsilon 0.9890503881725811 total_time 726.0
# episode 23, reward -69.0, memory_length 2000, epsilon 0.9885559865891906 total_time 726.0
# episode 24, reward -161.0, memory_length 2000, epsilon 0.9880618321448019 total_time 731.0
# episode 25, reward -75.0, memory_length 2000, epsilon 0.9875679247158765 total_time 724.0
# episode 26, reward -236.0, memory_length 2000, epsilon 0.9870742641789374 total_time 724.0
# episode 27, reward -346.0, memory_length 2000, epsilon 0.9865808504105695 total_time 722.0
# episode 28, reward -29.0, memory_length 2000, epsilon 0.9860876832874194 total_time 725.0
# episode 29, reward -345.0, memory_length 2000, epsilon 0.9855947626861951 total_time 725.0
# episode 30, reward -63.0, memory_length 2000, epsilon 0.9851020884836666 total_time 721.0
# episode 31, reward -111.0, memory_length 2000, epsilon 0.9846096605566654 total_time 727.0
# episode 32, reward 99.0, memory_length 2000, epsilon 0.9841174787820847 total_time 725.0
# episode 33, reward -468.0, memory_length 2000, epsilon 0.9836255430368785 total_time 730.0
# episode 34, reward -72.0, memory_length 2000, epsilon 0.9831338531980633 total_time 722.0
# episode 35, reward -310.0, memory_length 2000, epsilon 0.9826424091427166 total_time 724.0
# episode 36, reward -345.0, memory_length 2000, epsilon 0.9821512107479772 total_time 721.0
# episode 37, reward -144.0, memory_length 2000, epsilon 0.9816602578910456 total_time 732.0
# episode 38, reward -139.0, memory_length 2000, epsilon 0.9811695504491836 total_time 724.0
# episode 39, reward -131.0, memory_length 2000, epsilon 0.9806790882997144 total_time 725.0
# episode 40, reward -80.0, memory_length 2000, epsilon 0.9801888713200222 total_time 726.0
# episode 41, reward -292.0, memory_length 2000, epsilon 0.9796988993875532 total_time 725.0
# episode 42, reward -40.0, memory_length 2000, epsilon 0.9792091723798139 total_time 727.0
# episode 43, reward -291.0, memory_length 2000, epsilon 0.978719690174373 total_time 730.0
# episode 44, reward -189.0, memory_length 2000, epsilon 0.9782304526488595 total_time 725.0
# episode 45, reward 6.0, memory_length 2000, epsilon 0.9777414596809645 total_time 721.0
# episode 46, reward -66.0, memory_length 2000, epsilon 0.9772527111484394 total_time 730.0
# episode 47, reward 137.0, memory_length 2000, epsilon 0.9767642069290973 total_time 730.0
# episode 48, reward -223.0, memory_length 2000, epsilon 0.9762759469008118 total_time 723.0
# episode 49, reward -441.0, memory_length 2000, epsilon 0.9757879309415182 total_time 721.0
# episode 50, reward -219.0, memory_length 2000, epsilon 0.9753001589292124 total_time 727.0
# episode 51, reward -513.0, memory_length 2000, epsilon 0.9748126307419515 total_time 721.0
# episode 52, reward -247.0, memory_length 2000, epsilon 0.9743253462578533 total_time 729.0
# episode 53, reward -295.0, memory_length 2000, epsilon 0.9738383053550967 total_time 722.0
# episode 54, reward -83.0, memory_length 2000, epsilon 0.9733515079119216 total_time 731.0
# episode 55, reward -90.0, memory_length 2000, epsilon 0.9728649538066285 total_time 726.0
# episode 56, reward -636.0, memory_length 2000, epsilon 0.9723786429175789 total_time 722.0
# episode 57, reward -105.0, memory_length 2000, epsilon 0.9718925751231952 total_time 727.0
# episode 58, reward -252.0, memory_length 2000, epsilon 0.9714067503019602 total_time 722.0
# episode 59, reward -194.0, memory_length 2000, epsilon 0.9709211683324178 total_time 727.0
# episode 60, reward -117.0, memory_length 2000, epsilon 0.9704358290931727 total_time 721.0
# episode 61, reward -244.0, memory_length 2000, epsilon 0.9699507324628899 total_time 724.0
# episode 62, reward -256.0, memory_length 2000, epsilon 0.9694658783202952 total_time 726.0
# episode 63, reward -157.0, memory_length 2000, epsilon 0.9689812665441752 total_time 726.0
# episode 64, reward -145.0, memory_length 2000, epsilon 0.9684968970133768 total_time 724.0
# episode 65, reward -333.0, memory_length 2000, epsilon 0.9680127696068077 total_time 725.0
# episode 66, reward -171.0, memory_length 2000, epsilon 0.9675288842034362 total_time 721.0
# episode 67, reward 179.0, memory_length 2000, epsilon 0.9670452406822906 total_time 726.0
# episode 68, reward -148.0, memory_length 2000, epsilon 0.9665618389224603 total_time 723.0
# episode 69, reward -337.0, memory_length 2000, epsilon 0.9660786788030947 total_time 722.0
# episode 70, reward 132.0, memory_length 2000, epsilon 0.965595760203404 total_time 721.0
# episode 71, reward 113.0, memory_length 2000, epsilon 0.9651130830026582 total_time 732.0
# episode 72, reward 1.0, memory_length 2000, epsilon 0.9646306470801883 total_time 726.0
# episode 73, reward -363.0, memory_length 2000, epsilon 0.964148452315385 total_time 721.0
# episode 74, reward 122.0, memory_length 2000, epsilon 0.9636664985877 total_time 722.0
# episode 75, reward -479.0, memory_length 2000, epsilon 0.9631847857766447 total_time 723.0
# episode 76, reward -268.0, memory_length 2000, epsilon 0.9627033137617906 total_time 722.0
# episode 77, reward 231.0, memory_length 2000, epsilon 0.9622220824227702 total_time 721.0
# episode 78, reward 188.0, memory_length 2000, epsilon 0.9617410916392753 total_time 722.0
# episode 79, reward -394.0, memory_length 2000, epsilon 0.9612603412910584 total_time 722.0
# episode 80, reward -182.0, memory_length 2000, epsilon 0.9607798312579316 total_time 721.0
# episode 81, reward -11.0, memory_length 2000, epsilon 0.9602995614197679 total_time 725.0
# episode 82, reward 64.0, memory_length 2000, epsilon 0.9598195316564995 total_time 724.0
# episode 83, reward -540.0, memory_length 2000, epsilon 0.9593397418481189 total_time 725.0
# episode 84, reward -114.0, memory_length 2000, epsilon 0.9588601918746789 total_time 721.0
# episode 85, reward -126.0, memory_length 2000, epsilon 0.9583808816162918 total_time 721.0
# episode 86, reward -77.0, memory_length 2000, epsilon 0.95790181095313 total_time 721.0
# episode 87, reward -133.0, memory_length 2000, epsilon 0.9574229797654261 total_time 726.0
# episode 88, reward 98.0, memory_length 2000, epsilon 0.956944387933472 total_time 724.0
# episode 89, reward -193.0, memory_length 2000, epsilon 0.9564660353376199 total_time 728.0
# episode 90, reward -387.0, memory_length 2000, epsilon 0.9559879218582816 total_time 721.0
# episode 91, reward 29.0, memory_length 2000, epsilon 0.9555100473759288 total_time 730.0
# episode 92, reward -68.0, memory_length 2000, epsilon 0.9550324117710928 total_time 725.0
# episode 93, reward -120.0, memory_length 2000, epsilon 0.9545550149243647 total_time 723.0
# episode 94, reward -310.0, memory_length 2000, epsilon 0.9540778567163952 total_time 725.0
# episode 95, reward -25.0, memory_length 2000, epsilon 0.9536009370278951 total_time 721.0
# episode 96, reward -335.0, memory_length 2000, epsilon 0.953124255739634 total_time 721.0
# episode 97, reward -254.0, memory_length 2000, epsilon 0.9526478127324418 total_time 723.0
# episode 98, reward -233.0, memory_length 2000, epsilon 0.9521716078872079 total_time 725.0
# episode 99, reward -253.0, memory_length 2000, epsilon 0.9516956410848808 total_time 721.0
# 1835.5811216831207

# %%
state_tracked_sample = [agent.states_tracked[i] for i in range(len(agent.states_tracked)) if agent.states_tracked[i] < 1000]

# %% [markdown]
# ### Tracking Convergence

# %%
plt.figure(0, figsize=(16,7))
plt.title('Q_value for state [0,0,0]  action (0,2)')
xaxis = np.asarray(range(0, len(agent.states_tracked)))
plt.semilogy(xaxis,np.asarray(agent.states_tracked))
plt.show()

# %%
# Track rewards per episode
score_tracked_sample = [score_tracked[i] for i in range(len(score_tracked)) if (i % 4 == 0)]

plt.figure(0, figsize=(16,7))
plt.title('Rewards per episode')
xaxis = np.asarray(range(0, len(score_tracked_sample)))
plt.plot(xaxis,np.asarray(score_tracked_sample))
plt.show()

# %% [markdown]
# #### Epsilon-decay sample function

# %% [markdown]
# <div class="alert alert-block alert-info">
# Try building a similar epsilon-decay function for your model.
# </div>

# %%
time = np.arange(0,10000)
epsilon = []
for i in range(0,10000):
    epsilon.append(0 + (1 - 0) * np.exp(-0.0009*i))

# %%
plt.plot(time, epsilon)
plt.show()
